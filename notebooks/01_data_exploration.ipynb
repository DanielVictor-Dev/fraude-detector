# %%
# ✅ Análise Exploratória dos Dados

# Importação das bibliotecas
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Configuração dos gráficos
sns.set(style='whitegrid')
plt.rcParams['figure.figsize'] = (10, 6)

# ✅ 1. Carregar os Dados
df = pd.read_csv('../data/raw/dataset.csv')

# ✅ 2. Verificar as primeiras linhas
print("🔍 Primeiros registros do dataset:")
print(df.head())

# ✅ 3. Verificar informações gerais do dataset
print("\nℹ️ Informações do dataset:")
print(df.info())

# ✅ 4. Verificar se existem valores nulos
print("\n❓ Verificando valores nulos:")
print(df.isnull().sum())

# ✅ 5. Verificar estatísticas descritivas
print("\n📊 Estatísticas descritivas:")
print(df.describe())

# ✅ 6. Verificar distribuição da variável alvo (status_fraude)
print("\n🔍 Distribuição da variável alvo (status_fraude):")
print(df['status_fraude'].value_counts())

# ✅ 7. Plotar gráfico de distribuição da variável alvo
sns.countplot(data=df, x='status_fraude')
plt.title('Distribuição da Classe - Fraude')
plt.xlabel('Status Fraude (0 = Não Fraude, 1 = Fraude)')
plt.ylabel('Quantidade')
plt.savefig('../outputs/figures/distribuicao_classe.png')
plt.show()

# ✅ 8. Correlação entre variáveis numéricas
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='Blues', fmt='.2f')
plt.title('Mapa de Calor - Correlação entre Variáveis Numéricas')
plt.savefig('../outputs/figures/correlacao_variaveis.png')
plt.show()

# ✅ 9. Análise de algumas variáveis (Exemplo: Valor da transação)
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x='status_fraude', y='valor_transacao')
plt.title('Distribuição do Valor das Transações por Status de Fraude')
plt.xlabel('Status Fraude (0 = Não Fraude, 1 = Fraude)')
plt.ylabel('Valor da Transação')
plt.savefig('../outputs/figures/boxplot_valor_transacao.png')
plt.show()

# ✅ 10. Verificar balanceamento da variável alvo
fraude_percent = df['status_fraude'].value_counts(normalize=True) * 100
print("\n📊 Distribuição percentual da variável alvo:")
print(fraude_percent)
# Out:
# 🔍 Primeiros registros do dataset:
#    idade    renda  limite_credito  valor_transacao  horario_transacao  \
# 0     56  5813.36         9178.88           750.47                 10
# 1     53  5148.62        15565.97           443.80                 15
# 2     58  8537.04         5756.49           361.38                 12
# 3     41  3718.65        19852.18           135.31                 15
# 4     28  1000.00         7591.03            39.07                 14
#
#    tipo_estabelecimento dispositivo  distancia_residencia_km  \
# 0           Eletrônicos         Web                     0.68
# 1          Supermercado  App Mobile                     0.02
# 2           Eletrônicos         Web                     1.01
# 3              Farmácia  POS Físico                    16.88
# 4  Posto de Combustível  POS Físico                    24.66
#
#    tempo_cliente_meses  score_credito  historico_atrasos  \
# 0                   16            312                  1
# ...
